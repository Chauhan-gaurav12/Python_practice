# %% [markdown]
# 1. find the largest number in the list by the help of for loop

# %%
numbers=[222,45,78,5,98,87887,7889999,10]
max(numbers)
# Out:
# 7889999

# %%
for num in numbers:
    if num > largest:
        largest = num

print("The largest number is:", largest)
# Out:
# The largest number is: 7889999

# %%
list1=[12,23]
list1[1]=25
print(list1)
# Out:
# [12, 25]
