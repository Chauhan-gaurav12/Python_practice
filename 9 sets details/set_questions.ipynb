# %%
# find the maximum and minimum in the set 
a={23,34,54,65}
maximum=max(a)
print(maximum)
print(min(a))
# Out:
# 65
# 23

# %%
# write a program to find the common element in three list using set
a=[14,58,78,25]
b=[14,58,36,87,98,26]
c=[87,8,55,3,14,58]
new=[]
a=set(a)
b=set(b)
c=set(c)
print(type(a))
x=a.intersection(b).intersection(c)
print(x)
x=list(x)
print(type(x))

# one simple method is 
print(set(a)&set(b)&set(c))
# Out:
# <class 'set'>
# {58, 14}
# <class 'list'>
# {58, 14}

# %%
# Program to find the difference b/w two set
a={14,15,16,20}
b={14,16,36}
print(a.difference(b))
# Out:
# {20, 15}

# %%
# write  a program to remove the element from the set if it is in set
a={14,15,16,20}
b={14,16,36}
a.discard(14)
print(a)
# Out:
# {16, 20, 15}

# %%
# write a program to check the if a set is a subset of the another set
a={14,15,16,20}
b={72,36,18,72}
print(b.issubset(a))
print(a.issubset(a))
print(a.isdisjoint(b))
# Out:
# False
# True
# True
