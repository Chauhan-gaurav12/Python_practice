# %%
import datetime
x=datetime.datetime.now()
print(x)
# Out:
# 2025-10-07 23:19:37.441275

# %%
y=datetime.datetime(1994,12,15)
print(y)
print(y.strftime("%A")) #  This is use for print the day name 
print(y.strftime("%a"))
print(y.strftime("%Y"))
# Out:
# 1994-12-15 00:00:00
# Thursday
# Thu
# 1994

# %%
# to generate the random number
import random
x=random.randint(1,100)
print(x)
# Out:
# 82

# %%
# program to play game
import random
l=["Heads","tails"]
x=random.choice(l)
print(x)
# str=input("enter your choice(H/T): ")
# if(str=='h' or str=='H'):
#     print()
# Out:
# tails

# %%
# math module
import math
x=max(21,25,36)
print(x)
x1=pow(12,2) #for finding the power any number
print(x1)
b=math.sqrt(49)
print(b)
a=abs(-158)
print(a)
k=math.ceil(2.4) # it return next closes number
print(k)
f=math.floor(2.9)
print(f) # it return last closes number
# Out:
# 36
# 144
# 7.0
# 158
# 3
# 2
