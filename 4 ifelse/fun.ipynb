# %%
username =input("Enter the username...:")
password=int(input("Enter the password...: "))
# Out:
# Enter the username...: harshitch1
# Enter the password...:  6397106572

# %%
import webbrowser
print(".......Login to your Instagram Account........")
username_by_user=input("Enter the username.... = ").lower()
password_by_user= int(input("Enter the Password... ="))

if username==username_by_user and password==password_by_user:
    print("Correct Password........")
    print("We are logining.......")
    
    webbrowser.open("https://www.instagram.com/")
else:
    print("\n Wrong Username and  Password....")
    print("Please Enter correct Username and Password.....")
# Out:
# .......Login to your Instagram Account........
# Enter the username.... =  harshitch1
# Enter the Password... = 6397106572
# Correct Password........
# We are logining.......
